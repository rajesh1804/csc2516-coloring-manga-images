# %% [markdown]
# # Install

# %%
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix
# Out:
# Cloning into 'pytorch-CycleGAN-and-pix2pix'...
# remote: Enumerating objects: 2513, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 2513 (delta 0), reused 5 (delta 0), pack-reused 2508
# Receiving objects: 100% (2513/2513), 8.20 MiB | 16.75 MiB/s, done.
# Resolving deltas: 100% (1573/1573), done.

# %%
import os
os.chdir('/content/pytorch-CycleGAN-and-pix2pix')

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 65.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 83.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 KB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 24.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 26.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 3.9 MB/s eta 0:00:00
# ...
#   Created wheel for visdom: filename=visdom-0.2.4-py3-none-any.whl size=1408216 sha256=614697ee0785e77f6832ec88d7e85765f045d2c3ec45d3746221622478f36107
#   Stored in directory: /root/.cache/pip/wheels/58/9e/14/30f7cc4dafdd4d602fb00ca33c6edd1424fc0f5df10a02e060
# ...

# %% [markdown]
# # Training
#
#
#
# Change the `--dataroot` and `--name` to your own dataset's path and model's name. Use `--gpu_ids 0,1,..` to train on multiple GPUs and `--batch_size` to change the batch size.

# %%
# !python train.py --dataroot /content/gdrive/MyDrive/imgMangaColor --name imgMangaColor --model cycle_gan --display_id -1 --epoch 8 --n_epochs 3 --n_epochs_decay 3
# Out:
# ----------------- Options ---------------
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 256
#                  dataroot: /content/gdrive/MyDrive/imgMangaColor	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: -1                            	[default: 1]
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: 8                             	[default: latest]
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
# ...

# %% [markdown]
# #Converting to ZIP File

# %%
# !zip -r /content/pytorch-CycleGAN-and-pix2pix/results/imgMangaColor.zip /content/pytorch-CycleGAN-and-pix2pix/results/imgMangaColor
# Out:
# updating: content/pytorch-CycleGAN-and-pix2pix/results/imgMangaColor/ (stored 0%)
# updating: content/pytorch-CycleGAN-and-pix2pix/results/imgMangaColor/test_latest/ (stored 0%)
# updating: content/pytorch-CycleGAN-and-pix2pix/results/imgMangaColor/test_latest/images/ (stored 0%)
# updating: content/pytorch-CycleGAN-and-pix2pix/results/imgMangaColor/test_latest/images/Akiho_Rindou_fake.png (deflated 0%)
# updating: content/pytorch-CycleGAN-and-pix2pix/results/imgMangaColor/test_latest/images/Alexander_Howell_real.png (deflated 2%)
# updating: content/pytorch-CycleGAN-and-pix2pix/results/imgMangaColor/test_latest/images/Akane_Yushima_fake.png (deflated 0%)
# updating: content/pytorch-CycleGAN-and-pix2pix/results/imgMangaColor/test_latest/images/Akira_Miyamoto_real.png (deflated 3%)
# updating: content/pytorch-CycleGAN-and-pix2pix/results/imgMangaColor/test_latest/images/Adeltrud_Olter_fake.png (deflated 0%)
# ...

# %% [markdown]
# # Testing
#
#
#
# Change the `--dataroot` and `--name` to be consistent with your trained model's configuration.

# %%
# !python test.py --dataroot /content/gdrive/MyDrive/imgMangaColor/testA --name imgMangaColor --model test --no_dropout --num_test 1500
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: /content/gdrive/MyDrive/imgMangaColor/testA	[default: None]
#              dataset_mode: single
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: test
#              model_suffix:
#                n_layers_D: 3
#                      name: imgMangaColor                 	[default: experiment_name]
# ...

# %% [markdown]
# # Visualization

# %%
import matplotlib.pyplot as plt

img = plt.imread('/content/pytorch-CycleGAN-and-pix2pix/results/imgMangaColor/test_latest/images/Adeltrud_Olter_fake.png')
plt.imshow(img)

# %%
import matplotlib.pyplot as plt

img = plt.imread('/content/pytorch-CycleGAN-and-pix2pix/results/horse2zebra_pretrained/test_latest/images/Adeltrud_Olter_real.png')
plt.imshow(img)
